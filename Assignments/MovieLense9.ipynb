# %%
import pandas as pd
import os

# %%
# !pip install pandas 
# !pip install numpy

# %% [markdown]
# ### THIS NOTEBOOOK AUTHOR: Omeally Davis

# %% [markdown]
# ## INPUT VARIABLES

# %%
base="/home/james/Documents/Jupiter-files/ml-100k"

# %%
print(os.getcwd())
# Out:
# /home/james/Pandas

# %%
path = (os.getcwd())

# %%
os.chdir(base)

# %%
col1_Names=['User_ID','Movie_ID','Movie_Ratings','U_Timestamp']

Movieratings = pd.read_csv("/home/james/Documents/Jupiter-files/ml-100k/u.data",
sep="\t", header=None,names = col1_Names)
#Print Data in a table
Movieratings.head()
#Number of data rows dsplayed
#Movie_ratings[:10]
# Out:
#    User_ID  Movie_ID  Movie_Ratings  U_Timestamp
# 0      196       242              3    881250949
# 1      186       302              3    891717742
# 2       22       377              1    878887116
# 3      244        51              2    880606923
# 4      166       346              1    886397596

# %%
col3_names=['User_ID','User_Age','User_Gender','User_occupation','Zip_Code']

Userdetails = pd.read_csv("/home/james/Documents/Jupiter-files/ml-100k/u.user",
sep= "|" , header= None, names = col3_names, usecols = range(5), encoding = 'ISO-8859 -1') 

Userdetails.head()
Userdetails[:10]
# Out:
#    User_ID  User_Age User_Gender User_occupation Zip_Code
# 0        1        24           M      technician    85711
# 1        2        53           F           other    94043
# 2        3        23           M          writer    32067
# 3        4        24           M      technician    43537
# 4        5        33           F           other    15213
# 5        6        42           M       executive    98101
# 6        7        57           M   administrator    91344
# 7        8        36           M   administrator    05201
# 8        9        29           M         student    01002
# 9       10        53           M          lawyer    90703

# %%
col2_names=['Movie_ID','Movie_Title','Release_Date','Video_Release_date','Link']

Moviedetails = pd.read_csv("/home/james/Documents/Jupiter-files/ml-100k/u.item",
sep= "|" , header= None, names = col2_names, usecols = range(5), encoding = 'ISO-8859 -1') 

Moviedetails.head()
#Moviedetails[:10]
# Out:
#    Movie_ID        Movie_Title Release_Date  Video_Release_date  \
# 0         1   Toy Story (1995)  01-Jan-1995                 NaN
# 1         2   GoldenEye (1995)  01-Jan-1995                 NaN
# 2         3  Four Rooms (1995)  01-Jan-1995                 NaN
# 3         4  Get Shorty (1995)  01-Jan-1995                 NaN
# 4         5     Copycat (1995)  01-Jan-1995                 NaN
#
#                                                 Link
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...
# 1  http://us.imdb.com/M/title-exact?GoldenEye%20(...
# 2  http://us.imdb.com/M/title-exact?Four%20Rooms%...
# 3  http://us.imdb.com/M/title-exact?Get%20Shorty%...
# 4  http://us.imdb.com/M/title-exact?Copycat%20(1995)

# %%
Merge_MovieId = pd.merge(on="Movie_ID", right=Movieratings,left=Moviedetails)
#Merge_MovieId = pd.merge(Moviedetails, Movieratings)
Merge_MovieId.head()
#Merge_MovieId[:10]
#All_Merge[:10]
# Out:
#    Movie_ID       Movie_Title Release_Date  Video_Release_date  \
# 0         1  Toy Story (1995)  01-Jan-1995                 NaN
# 1         1  Toy Story (1995)  01-Jan-1995                 NaN
# 2         1  Toy Story (1995)  01-Jan-1995                 NaN
# 3         1  Toy Story (1995)  01-Jan-1995                 NaN
# 4         1  Toy Story (1995)  01-Jan-1995                 NaN
#
#                                                 Link  User_ID  Movie_Ratings  \
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...      308              4
# 1  http://us.imdb.com/M/title-exact?Toy%20Story%2...      287              5
# 2  http://us.imdb.com/M/title-exact?Toy%20Story%2...      148              4
# 3  http://us.imdb.com/M/title-exact?Toy%20Story%2...      280              4
# 4  http://us.imdb.com/M/title-exact?Toy%20Story%2...       66              3
#
#    U_Timestamp
# 0    887736532
# 1    875334088
# 2    877019411
# 3    891700426
# 4    883601324

# %%
All_Merge = pd.merge(Userdetails, Merge_MovieId)
#Merge_MovieId.head()
#Merge_MovieId[:10]
All_Merge.head()
All_Merge[:10]
# Out:
#    User_ID  User_Age User_Gender User_occupation Zip_Code  Movie_ID  \
# 0        1        24           M      technician    85711         1
# 1        1        24           M      technician    85711         2
# 2        1        24           M      technician    85711         3
# 3        1        24           M      technician    85711         4
# 4        1        24           M      technician    85711         5
# 5        1        24           M      technician    85711         6
# 6        1        24           M      technician    85711         7
# 7        1        24           M      technician    85711         8
# 8        1        24           M      technician    85711         9
# 9        1        24           M      technician    85711        10
#
#                                          Movie_Title Release_Date  \
# 0                                   Toy Story (1995)  01-Jan-1995
# 1                                   GoldenEye (1995)  01-Jan-1995
# ...

# %%
#Merging data sets (Movie_ratings and Movie_details via Movie_ID)
#Merge_MovieId = pd.merge(Movie_details,Movie_ratings)
#Merge_MovieId = pd.concat( [Movie_ratings,Movie_details], axis = 1)
#Merge_Movie_ratings = pd.merge(on="Movie_ID", right=Movie_ratings,left=Movie_details)
#All_Merge = pd.concat([User_details, Merge_MovieId], axis = 1)
#All_Merge = pd.merge(User_details, Merge_MovieId)
#Merge_MovieId.head()
#Merge_MovieId[:10]
#All_Merge[:100

# %%
#Q1 Print a list of the 10 movies that received the most number of ratings.
#Print a list of the 10 movies that received the most number of ratings, sorted by the number of ratings. 
#Top_R = Merge_MovieId.groupby('Movie_Title').size().sort_values( ascending=False)[:10]
Top_R = All_Merge.groupby('Movie_Title').size().sort_values( 
ascending=False)
Top_R.head()


print('Top rated movies are:\n', Top_R[:10])
# Out:
# Top rated movies are:
#  Movie_Title
# Star Wars (1977)                 583
# Contact (1997)                   509
# Fargo (1996)                     508
# Return of the Jedi (1983)        507
# Liar Liar (1997)                 485
# English Patient, The (1996)      481
# Scream (1996)                    478
# Toy Story (1995)                 452
# Air Force One (1997)             431
# Independence Day (ID4) (1996)    429
# dtype: int64

# %%
#Q2 Print a list of the 10 movies that received the most number of ratings, sorted by the number of ratings. 
print('Top rated movies are:\n' '                                Sorted \n', Top_R[:10])
# Out:
# Top rated movies are:
#                                 Sorted
#  Movie_Title
# Star Wars (1977)                 583
# Contact (1997)                   509
# Fargo (1996)                     508
# Return of the Jedi (1983)        507
# Liar Liar (1997)                 485
# English Patient, The (1996)      481
# Scream (1996)                    478
# Toy Story (1995)                 452
# Air Force One (1997)             431
# Independence Day (ID4) (1996)    429
# dtype: int64

# %%
#Q3 Print a list of the number of ratings received by each genre.

# %%
#Q4 Print the oldest movie with a “5*” rating.
old = All_Merge[['Movie_Title', 'Movie_Ratings', 'Release_Date']]
old = old[(old['Release_Date'] == old['Release_Date'].min()) & (old['Movie_Ratings'] ==5)]
# Out:
# -----------------------------------------------------------
# TypeError                 Traceback (most recent call last)
# <ipython-input-30-a77ef1d4885c> in <module>
#       1 #Q4 Print the oldest movie with a “5*” rating.
#       2 old = All_Merge[['Movie_Title', 'Movie_Ratings', 'Release_Date']]
# ----> 3 old = old[(old['Release_Date'] == old['Release_Date'].min()) & (old['Movie_Ratings'] ==5)]
#
# ~/Pandas/Pandasv/lib/python3.6/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11214         return self._reduce(
# > 11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#   11217
#
# ~/Pandas/Pandasv/lib/python3.6/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
# ...

# %%
#Q5 Print a list of the genre of the top 10 most rated movies.

# %%
#Q6 Print the title of the movie that was rated the most by students

Studentmr = All_Merge[(All_Merge['User_occupation']=='student')].groupby('Movie_Title').count().sort_values(['Movie_Ratings'], ascending = False)
Studentmr.head()
#Studentmr[:1]
Studentmr[['Movie_Ratings']][:1]
# Out:
#                Movie_Ratings
# Movie_Title
# Scream (1996)            137

# %%
#Q7 Print the list of movies that received the highest number of “5” rating 
#x=Merge_MovieId.groupby('Movie_Title')['Movie_Ratings'].mean().sort_values(ascending = False)
#x=Merge_MovieId.groupby('Movie_Title')['Movie_Ratings'].count().sort_values(ascending = False)
y = Merge_MovieId[Merge_MovieId['Movie_Ratings']==5]['Movie_Title'].value_counts(sort=True)
#x.head()
y.head()
#x[:10]
y[:10]
# Out:
# Star Wars (1977)                    325
# Fargo (1996)                        227
# Godfather, The (1972)               214
# Raiders of the Lost Ark (1981)      202
# Pulp Fiction (1994)                 188
# Schindler's List (1993)             186
# Silence of the Lambs, The (1991)    181
# Titanic (1997)                      179
# Empire Strikes Back, The (1980)     172
# Return of the Jedi (1983)           171
# Name: Movie_Title, dtype: int64

# %%
#Q8 Print the list of zip codes corresponding to the highest number of users that rated movies. 
Top_Z = All_Merge.groupby('Zip_Code').size().sort_values( 
ascending=False)
Top_Z.head()
Top_Z[:10]
#'Zip_Code'
#'User_occupation'
# Out:
# Zip_Code
# 55414    1103
# 20009     878
# 10019     850
# 22902     832
# 61820     817
# 48103     746
# 10003     736
# 60657     685
# 80525     678
# 83702     639
# dtype: int64

# %%
#Q9 Find the most rated movie by users in the age group 20 to 25.
Age2025 = All_Merge[(All_Merge['User_Age'] >= 20) & (All_Merge['User_Age'] <= 25)].groupby('Movie_Title').count().sort_values(['Movie_Ratings'], ascending = False)
#Studentmr.head()
Age2025.head()
#Studentmr[:1]
#Studentmr[['Movie_Ratings']][:1]
Age2025[['Movie_Ratings']][:1]
# Out:
#                Movie_Ratings
# Movie_Title
# Scream (1996)            130

# %%
#Q10 Print the list of movies that were rate after year 1960.
import datetime 
from datetime import date
startdate= datetime.date(1960,1,1)
fstartdate = startdate.strftime('%d-%b-%Y')
#print (fstartdate)
af_startdate = All_Merge[All_Merge['Release_Date'] >= fstartdate]
af_startdate.head()
af_startdate[:10]
# Out:
#    User_ID  User_Age User_Gender User_occupation Zip_Code  Movie_ID  \
# 0        1        24           M      technician    85711         1
# 1        1        24           M      technician    85711         2
# 2        1        24           M      technician    85711         3
# 3        1        24           M      technician    85711         4
# 4        1        24           M      technician    85711         5
# 5        1        24           M      technician    85711         6
# 6        1        24           M      technician    85711         7
# 7        1        24           M      technician    85711         8
# 8        1        24           M      technician    85711         9
# 9        1        24           M      technician    85711        10
#
#                                          Movie_Title Release_Date  \
# 0                                   Toy Story (1995)  01-Jan-1995
# 1                                   GoldenEye (1995)  01-Jan-1995
# ...

# %%
col3_names=['Genre','Number_of_Rating']

Genre_Rating = pd.read_csv("/home/james/Documents/Jupiter-files/ml-100k/u.genre",
sep= "|" , header= None, names = col3_names, usecols = range(2), encoding = 'ISO-8859 -1') 

Genre_Rating.head()
Genre_Rating[:20]
# Out:
#           Genre  Number_of_Rating
# 0       unknown                 0
# 1        Action                 1
# 2     Adventure                 2
# 3     Animation                 3
# 4    Children's                 4
# 5        Comedy                 5
# 6         Crime                 6
# 7   Documentary                 7
# 8         Drama                 8
# 9       Fantasy                 9
# 10    Film-Noir                10
# 11       Horror                11
# 12      Musical                12
# 13      Mystery                13
# 14      Romance                14
# 15       Sci-Fi                15
# 16     Thriller                16
# 17          War                17
# 18      Western                18
